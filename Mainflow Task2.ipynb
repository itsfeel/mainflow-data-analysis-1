# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\user\Downloads\csv mainflow.csv.csv")

# %%
dataset.head()
# Out:
#   Observatio Y-Kappa  ChipRat Unnamed: 3    BF- Unnamed: 5  BlowFlow  \
# 0   31-00:00       n   23.100          e  16.52    CMratio   121.717
# 1   31-01:00    27.6      NaN      16.81    NaN     79.022  1328.360
# 2   31-02:00   23.19   16.709        NaN    NaN     79.562  1329.407
# 3   31-03:00    23.6   16.478        NaN    NaN     81.011  1334.877
# 4   31-04:00    22.9   15.618        NaN    NaN     93.244  1334.168
#
#    ChipLevel4  T-upperExt-2  T-lowerExt-2  ...  Lower-HeatT- Upper-HeatT-3  \
# 0    1177.607       169.805       358.282  ...        67.122         3.000
# 1     341.327       351.050       329.067  ...        60.012       330.823
# 2     239.161       350.022       329.260  ...           NaN       329.140
# 3     213.527       350.938       331.142  ...        68.496       328.875
# 4     243.131       351.640       332.709  ...        70.022       328.352
#
#    ChipMass-4  WeakLiquorF  BlackFlow-2  WeakWashF  SteamHeatF-3  \
# ...

# %%
dataset.tail()
# Out:
#     Observatio Y-Kappa  ChipRat Unnamed: 3       BF- Unnamed: 5  BlowFlow  \
# 319   10-16:00   23.75   12.667      93.45  1178.252    276.955   347.286
# 320    9-19:00    19.8   12.558     94.352  1184.119    297.071   399.135
# 321    9-20:00   23.01   12.550     90.842  1188.517    289.826   373.633
# 322    9-21:00   24.32   13.083      88.91  1192.879    318.006   364.081
# 323    9-22:00   25.75   13.417     85.451  1186.342    248.312   356.289
#
#      ChipLevel4  T-upperExt-2  T-lowerExt-2  ...  Lower-HeatT- Upper-HeatT-3  \
# 319     310.970         1.523       513.956  ...       148.174      1027.201
# 320     319.576         1.451       570.058  ...       165.178       906.962
# 321     314.591         1.457       549.306  ...       160.841       887.125
# 322     308.559         1.523       504.852  ...       147.589       804.423
# 323     310.482         1.474       497.375  ...       144.218       828.328
#
# ...

# %%
# Filtering rows where 'ChipRat' > 5
filtered_dataset = dataset[dataset['ChipRat'] > 5]
print("Filtered Data (ChipRat > 5):")
print(filtered_dataset.head())
# Out:
# Filtered Data (ChipRat > 5):
#   Observatio Y-Kappa  ChipRat Unnamed: 3    BF- Unnamed: 5  BlowFlow  \
# 0   31-00:00       n   23.100          e  16.52    CMratio   121.717
# 2   31-02:00   23.19   16.709        NaN    NaN     79.562  1329.407
# 3   31-03:00    23.6   16.478        NaN    NaN     81.011  1334.877
# 4   31-04:00    22.9   15.618        NaN    NaN     93.244  1334.168
# 8   31-07:00    22.5   14.233        NaN    NaN     97.249  1346.900
#
#    ChipLevel4  T-upperExt-2  T-lowerExt-2  ...  Lower-HeatT- Upper-HeatT-3  \
# 0    1177.607       169.805       358.282  ...        67.122         3.000
# 2     239.161       350.022       329.260  ...           NaN       329.140
# 3     213.527       350.938       331.142  ...        68.496       328.875
# 4     243.131       351.640       332.709  ...        70.022       328.352
# 8     330.325       352.687       328.894  ...           NaN       331.485
#
#    ChipMass-4  WeakLiquorF  BlackFlow-2  WeakWashF  SteamHeatF-3  \
# ...

# %%
# i'm handling missing values here
# Drop rows with any missing values
cleaned_dataset = dataset.dropna()
print("Cleaned Data (Dropped missing values):")
print(cleaned_dataset.head())
# Out:
# Cleaned Data (Dropped missing values):
#   Observatio Y-Kappa  ChipRat Unnamed: 3    BF- Unnamed: 5  BlowFlow  \
# 0   31-00:00       n     23.1          e  16.52    CMratio   121.717
#
#    ChipLevel4  T-upperExt-2  T-lowerExt-2  ...  Lower-HeatT- Upper-HeatT-3  \
# 0    1177.607       169.805       358.282  ...        67.122           3.0
#
#    ChipMass-4  WeakLiquorF  BlackFlow-2  WeakWashF  SteamHeatF-3  \
# 0     329.432      303.099      175.964   1127.197      1319.039
#
#    T-Top-Chips-4  SulphidityL-4  Unnamed: 25
# 0        257.325         54.612      252.077
#
# [1 rows x 26 columns]

# %%
# I'm calculating summary stats here

# Let's assume dataset is a DataFrame and Y-Kappa is the column in question

print(dataset.head())

print(dataset['Y-Kappa'].unique())  

dataset['Y-Kappa'] = pd.to_numeric(dataset['Y-Kappa'], errors='coerce')


print(dataset['Y-Kappa'].isna().sum())  # This tells you how many NaN values are in the column

median_y_kappa = dataset['Y-Kappa'].median()

print("Median of 'Y-Kappa':", median_y_kappa)
# Out:
#   Observatio Y-Kappa  ChipRat Unnamed: 3    BF- Unnamed: 5  BlowFlow  \
# 0   31-00:00       n   23.100          e  16.52    CMratio   121.717
# 1   31-01:00    27.6      NaN      16.81    NaN     79.022  1328.360
# 2   31-02:00   23.19   16.709        NaN    NaN     79.562  1329.407
# 3   31-03:00    23.6   16.478        NaN    NaN     81.011  1334.877
# 4   31-04:00    22.9   15.618        NaN    NaN     93.244  1334.168
#
#    ChipLevel4  T-upperExt-2  T-lowerExt-2  ...  Lower-HeatT- Upper-HeatT-3  \
# 0    1177.607       169.805       358.282  ...        67.122         3.000
# 1     341.327       351.050       329.067  ...        60.012       330.823
# 2     239.161       350.022       329.260  ...           NaN       329.140
# 3     213.527       350.938       331.142  ...        68.496       328.875
# 4     243.131       351.640       332.709  ...        70.022       328.352
#
#    ChipMass-4  WeakLiquorF  BlackFlow-2  WeakWashF  SteamHeatF-3  \
# ...
